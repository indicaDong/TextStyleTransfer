# %%
# !git clone https://github.com/HongyuGong/TextStyleTransfer
# Out:
# fatal: destination path 'TextStyleTransfer' already exists and is not an empty directory.

# %%
# %cd /content/TextStyleTransfer
# Out:
# /content/TextStyleTransfer

# %%
# !mkdir pretrained_model
# !mkdir model

# %%
# !cp -r /content/drive/MyDrive/data/DATA /content/TextStyleTransfer

# %%
# %cd /content/TextStyleTransfer/src
# Out:
# /content/TextStyleTransfer/src

# %%
# !cp -r /content/drive/MyDrive/dump  /content/TextStyleTransfer

# %%
# !python3 corpus_helper.py --data DATA --vec_dim 100 --embed_fn /content/drive/MyDrive/glove.6B.50d1.txt
# Out:
# saving corpus data to pkl...
# corpus_helper.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   shuffled_sent_list = np.array(sent_list)[shuffled_indices]
# fn size: 177218
# done shuffling and transforming txt to pickle...
# fn size: 266041
# done shuffling and transforming txt to pickle...
# fn size: 2000
# done shuffling and transforming txt to pickle...
# fn size: 2000
# done shuffling and transforming txt to pickle...
# fn size: 500
# done shuffling and transforming txt to pickle...
# fn size: 500
# done shuffling and transforming txt to pickle...
# build vocabulary and embedding...
# Extra words: ['<TOS>', '<EOS>', '<UNK>']
# <EOS> in vocab: 1
# Joint vocab size: 9571
# ...

# %%
# !pip uninstall tensorflow
# !pip3 install tensorflow==1.14
# Out:
# Found existing installation: tensorflow 1.14.0
# Uninstalling tensorflow-1.14.0:
#   Would remove:
#     /usr/local/bin/freeze_graph
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-1.14.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-1.14.0
# y
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.14.0 which is incompatible.
# ...

# %%
# !python3 style_transfer_RL.py --data_type yelp --max_sent_len 18 --lm_seq_length 18 --lm_epochs 3 --style_epochs 1 --pretrain_epochs 2 --beam_width 1 --pretrained_model_path best_pretrained_model --batch_size 32
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# I0616 10:40:16.065903 140578806990720 dictionary.py:199] adding document #0 to Dictionary(0 unique tokens: [])
# I0616 10:40:16.066081 140578806990720 dictionary.py:206] built Dictionary(14 unique tokens: ["'ll", "'s", '.', 'back', 'but']...) from 2 documents (total 20 corpus positions)
# I0616 10:40:16.068489 140578806990720 dictionary.py:199] adding document #0 to Dictionary(0 unique tokens: [])
# I0616 10:40:16.068646 140578806990720 dictionary.py:206] built Dictionary(10 unique tokens: ['.', 'done', 'i', 'immediately', 'place']...) from 2 documents (total 18 corpus positions)
# I0616 10:40:16.070800 140578806990720 dictionary.py:199] adding document #0 to Dictionary(0 unique tokens: [])
# I0616 10:40:16.070973 140578806990720 dictionary.py:206] built Dictionary(8 unique tokens: ['.', 'customer', 'has', 'horrible', 'place']...) from 2 documents (total 15 corpus positions)
# ...

# %%
# !python3 style_transfer_test.py --data_type yelp --max_sent_len 18 --lm_seq_length 18 --use_beamsearch_decode --beam_width 1 --model_path "/content/TextStyleTransfer/model" --output_path OUTPUT_PATH --batch_size 32
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
